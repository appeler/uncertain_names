# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.5.0
# 2.5.1

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

NGRAMS = 2
SAMPLE = 1000000
EPOCHS = 20

# Florida voter
df = pd.read_csv('../dataverse_files/fl_voter_reg/fl_reg_name_race.csv.gz')
df.dropna(subset=['name_first', 'name_last'], inplace=True)
df['race'] = df.race.map({'native_indian': 'other', 'asian': 'asian', 'nh_black': 'nh_black', 'hispanic': 'hispanic', 'nh_white': 'nh_white', 'other': 'other', 'multi_racial': 'other', 'unknown': 'unknown'})
df
# Out:
#            name_first  name_last      race
# 0              Walker  Elizabeth  nh_white
# 1              Palmer      Alton  nh_white
# 2            Mc Cleod     Alicia  nh_black
# 3         Scarborough       Dale  nh_white
# 4              Walker     Daniel  nh_white
# ...               ...        ...       ...
# 13653889      Walters    William  nh_white
# 13653890       Sawyer    Matthew  nh_white
# 13653891       Thomas     Janine  nh_white
# 13653892     Campbell      Angel     other
# 13653893       Bruner        Jeb  nh_white
#
# [13653894 rows x 3 columns]

# %%
sdf = df[df.race.isin(['unknown']) == False].groupby(['race']).sample(int(SAMPLE/5), random_state=21)
del df

# Additional features
sdf['name_last'] = sdf.name_last.str.title()
sdf
# Out:
#          name_first   name_last   race
# 779856       Kelley          Mi  asian
# 10722411     Pitman       Ariel  asian
# 9871739       PATEL  Ranjanbala  asian
# 6278811        Inch     Corazon  asian
# 6085057      Mathew       Lilly  asian
# ...             ...         ...    ...
# 2308712      CASTRO      Gisele  other
# 5945501      Brooks       Dyron  other
# 8160933      Carson        Mary  other
# 8397639        AMER      Ossama  other
# 300768        SALEH       Rania  other
#
# [800000 rows x 3 columns]

# %%
rdf = sdf.groupby('race').agg({'name_last': 'count'})
rdf.to_csv('../dataverse_files/fl_voter_reg/lstm/fl_ln_five_cat_race.csv', columns=[])
rdf
# Out:
#           name_last
# race
# asian        200000
# nh_black     200000
# nh_white     200000
# other        200000

# %%
sdf.groupby('race').agg({'name_last': 'nunique'})
# Out:
#           name_last
# race
# asian         49116
# nh_black      43038
# nh_white      12241
# other         35977

# %% [markdown]
# ## Preprocessing the input data

# %%
# last name only
sdf['name_last_name_first'] = sdf['name_last']

# build n-gram list
vect = CountVectorizer(analyzer='char', max_df=0.3, min_df=3, ngram_range=(NGRAMS, NGRAMS), lowercase=False) 
a = vect.fit_transform(sdf.name_last_name_first)
vocab = vect.vocabulary_

# sort n-gram by freq (highest -> lowest)
words = []
for b in vocab:
    c = vocab[b]
    #print(b, c, a[:, c].sum())
    words.append((a[:, c].sum(), b))
    #break
words = sorted(words, reverse=True)
words_list = [w[1] for w in words]
num_words = len(words_list)
print("num_words = %d" % num_words)


def find_ngrams(text, n):
    a = zip(*[text[i:] for i in range(n)])
    wi = []
    for i in a:
        w = ''.join(i)
        try:
            idx = words_list.index(w)
        except:
            idx = 0
        wi.append(idx)
    return wi

# build X from index of n-gram sequence
X = np.array(sdf.name_last_name_first.apply(lambda c: find_ngrams(c, NGRAMS)))

# check max/avg feature
X_len = []
for x in X:
    X_len.append(len(x))

max_feature_len = max(X_len)
avg_feature_len = int(np.mean(X_len))

print("Max feature len = %d, Avg. feature len = %d" % (max_feature_len, avg_feature_len))
y = np.array(sdf.race.astype('category').cat.codes)

# Split train and test dataset
X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)
# Out:
# num_words = 1201
# Max feature len = 22, Avg. feature len = 5

# %% [markdown]
# ## Train a LSTM model
#
# ref: http://machinelearningmastery.com/sequence-classification-lstm-recurrent-neural-networks-python-keras/

# %%
'''The dataset is actually too small for LSTM to be of any advantage
compared to simpler, much faster methods such as TF-IDF + LogReg.
Notes:

- RNNs are tricky. Choice of batch size is important,
choice of loss and optimizer is critical, etc.
Some configurations won't converge.

- LSTM loss decrease patterns during training can be quite different
from what you see with CNNs/MLPs/etc.
'''
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, Activation
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import load_model

max_features = num_words # 20000
feature_len = 20 # avg_feature_len # cut texts after this number of words (among top max_features most common words)
batch_size = 32

print(len(X_train), 'train sequences')
print(len(X_test), 'test sequences')

print('Pad sequences (samples x time)')
X_train = sequence.pad_sequences(X_train, maxlen=feature_len)
X_test = sequence.pad_sequences(X_test, maxlen=feature_len)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)

num_classes = np.max(y_train) + 1
print(num_classes, 'classes')

print('Convert class vector to binary class matrix '
      '(for use with categorical_crossentropy)')
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# 640000 train sequences
# 160000 test sequences
# Pad sequences (samples x time)
# X_train shape: (640000, 20)
# X_test shape: (160000, 20)
# 4 classes
# Convert class vector to binary class matrix (for use with categorical_crossentropy)
# y_train shape: (640000, 4)
# y_test shape: (160000, 4)

# %%
print('Build model...')

input_ = keras.layers.Input(shape=(feature_len))
layer_ = Embedding(num_words, 32) (input_)
layer_ = LSTM(128, dropout=0.2, recurrent_dropout=0.2)(layer_, training=True)
output = Dense(num_classes, activation='softmax') (layer_)

model = keras.models.Model(inputs=input_, outputs=output)

# try using different optimizers and different optimizer configs
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())
# Out:
# Build model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 20, 32)            38432
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               82432
# _________________________________________________________________
# dense (Dense)                (None, 4)                 516
# =================================================================
# Total params: 121,380
# Trainable params: 121,380
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print('Train...')
model.fit(X_train, y_train, batch_size=batch_size, epochs=EPOCHS,
          validation_split=0.1, verbose=1)
score, acc = model.evaluate(X_test, y_test,
                            batch_size=batch_size, verbose=1)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Train...
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2610ff886c74> in <module>
#       1 print('Train...')
# ----> 2 model.fit(X_train, y_train, batch_size=batch_size, epochs=EPOCHS,
#       3           validation_split=0.1, verbose=1)
#       4 score, acc = model.evaluate(X_test, y_test,
#       5                             batch_size=batch_size, verbose=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     973           # TODO(mdan): Push this block higher in tf.function's call stack.
#     974           try:
# --> 975             return autograph.converted_call(
#     976                 original_func,
#     977                 args,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__step_function(model, iterator)
#      27                         return fscope_1.ret(retval__1, do_return_1)
#      28                 data = ag__.converted_call(ag__.ld(next), (ag__.ld(iterator),), None, fscope)
# ---> 29                 outputs = ag__.converted_call(ag__.ld(model).distribute_strategy.run, (ag__.ld(run_step),), dict(args=(ag__.ld(data),)), fscope)
#      30                 outputs = ag__.converted_call(ag__.ld(reduce_per_replica), (ag__.ld(outputs), ag__.ld(self).distribute_strategy), dict(reduction='first'), fscope)
#      31                 ag__.converted_call(ag__.ld(write_scalar_summaries), (ag__.ld(outputs),), dict(step=ag__.ld(model)._train_counter), fscope)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1283       fn = autograph.tf_convert(
#    1284           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1285       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1286
#    1287   def reduce(self, reduce_op, value, axis):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2831       kwargs = {}
#    2832     with self._container_strategy().scope():
# -> 2833       return self._call_for_each_replica(fn, args, kwargs)
#    2834
#    2835   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3606   def _call_for_each_replica(self, fn, args, kwargs):
#    3607     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3608       return fn(*args, **kwargs)
#    3609
#    3610   def _reduce_to(self, reduce_op, value, destinations, options):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in run_step(data)
#      16                         do_return_1 = False
#      17                         retval__1 = ag__.UndefinedReturnValue()
# ---> 18                         outputs = ag__.converted_call(ag__.ld(model).train_step, (ag__.ld(data),), None, fscope_1)
#      19                         with ag__.ld(tf).control_dependencies(ag__.ld(_minimum_control_deps)(ag__.ld(outputs))):
#      20                             ag__.converted_call(ag__.ld(model)._train_counter.assign_add, (1,), None, fscope_1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     444         result = converted_f(*effective_args, **kwargs)
#     445       else:
# --> 446         result = converted_f(*effective_args)
#     447     except Exception as e:
#     448       _attach_error_metadata(e, converted_f)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in tf__train_step(self, data)
#      12                 (x, y, sample_weight) = ag__.converted_call(ag__.ld(data_adapter).unpack_x_y_sample_weight, (ag__.ld(data),), None, fscope)
#      13                 with ag__.ld(tf).GradientTape() as tape:
# ---> 14                     y_pred = ag__.converted_call(ag__.ld(self), (ag__.ld(x),), dict(training=True), fscope)
#      15                     loss = ag__.converted_call(ag__.ld(self).compiled_loss, (ag__.ld(y), ag__.ld(y_pred), ag__.ld(sample_weight)), dict(regularization_losses=ag__.ld(self).losses), fscope)
#      16                 ag__.converted_call(ag__.ld(self).optimizer.minimize, (ag__.ld(loss), ag__.ld(self).trainable_variables), dict(tape=ag__.ld(tape)), fscope)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py in tf____call__(self, *args, **kwargs)
#     197                 mask_is_implicit = ag__.Undefined('mask_is_implicit')
#     198                 outputs = ag__.Undefined('outputs')
# --> 199                 ag__.if_stmt(ag__.converted_call(ag__.ld(_in_functional_construction_mode), (ag__.ld(self), ag__.ld(inputs), ag__.ld(args), ag__.ld(kwargs), ag__.ld(input_list)), None, fscope), if_body_10, else_body_10, get_state_10, set_state_10, ('do_return', "kwargs['mask']", 'retval_', 'args', 'input_list', 'inputs', 'kwargs'), 3)
#     200                 return fscope.ret(retval_, do_return)
#     201         return tf____call__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py in else_body_10()
#     143                             ag__.if_stmt(ag__.ld(self)._autocast, if_body_6, else_body_6, get_state_6, set_state_6, ('inputs',), 1)
#     144                             with ag__.ld(autocast_variable).enable_auto_cast_variables(ag__.ld(self)._compute_dtype_object):
# --> 145                                 outputs = ag__.converted_call(ag__.ld(call_fn), ((ag__.ld(inputs),) + tuple(ag__.ld(args))), dict(**ag__.ld(kwargs)), fscope)
#     146
#     147                             def get_state_7():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in tf__call(self, inputs, training, mask)
#      11                 try:
#      12                     do_return = True
# ---> 13                     retval_ = ag__.converted_call(ag__.ld(self)._run_internal_graph, (ag__.ld(inputs),), dict(training=ag__.ld(training), mask=ag__.ld(mask)), fscope)
#      14                 except:
#      15                     do_return = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in tf___run_internal_graph(self, inputs, training, mask)
#     160                 args = ag__.Undefined('args')
#     161                 outputs = ag__.Undefined('outputs')
# --> 162                 ag__.for_stmt(ag__.ld(depth_keys), None, loop_body_4, get_state_9, set_state_9, (), {'iterate_names': 'depth'})
#     163                 output_tensors = []
#     164
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     441
#     442   else:
# --> 443     _py_for_stmt(iter_, extra_test, body, None, None)
#     444
#     445
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     470   else:
#     471     for target in iter_:
# --> 472       body(target)
#     473
#     474
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     456     original_body = body
#     457     def protected_body(protected_iter):
# --> 458       original_body(protected_iter)
#     459       after_iteration()
#     460       before_iteration()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in loop_body_4(itr_4)
#     152                             pass
#     153                         ag__.if_stmt(ag__.not_(continue__3), if_body_4, else_body_4, get_state_7, set_state_7, ('continue__3',), 0)
# --> 154                     ag__.for_stmt(ag__.ld(nodes), None, loop_body_3, get_state_8, set_state_8, (), {'iterate_names': 'node'})
#     155                 nodes = ag__.Undefined('nodes')
#     156                 kwargs = ag__.Undefined('kwargs')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     441
#     442   else:
# --> 443     _py_for_stmt(iter_, extra_test, body, None, None)
#     444
#     445
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     470   else:
#     471     for target in iter_:
# --> 472       body(target)
#     473
#     474
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     456     original_body = body
#     457     def protected_body(protected_iter):
# --> 458       original_body(protected_iter)
#     459       after_iteration()
#     460       before_iteration()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in loop_body_3(itr_3)
#     151                             nonlocal continue__3
#     152                             pass
# --> 153                         ag__.if_stmt(ag__.not_(continue__3), if_body_4, else_body_4, get_state_7, set_state_7, ('continue__3',), 0)
#     154                     ag__.for_stmt(ag__.ld(nodes), None, loop_body_3, get_state_8, set_state_8, (), {'iterate_names': 'node'})
#     155                 nodes = ag__.Undefined('nodes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in if_body_4()
#     146                             def else_body_3():
#     147                                 pass
# --> 148                             ag__.if_stmt(ag__.not_(continue__3), if_body_3, else_body_3, get_state_6, set_state_6, (), 0)
#     149
#     150                         def else_body_4():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py in if_body_3()
#     131                             def if_body_3():
#     132                                 (args, kwargs) = ag__.converted_call(ag__.ld(node).map_arguments, (ag__.ld(tensor_dict),), None, fscope)
# --> 133                                 outputs = ag__.converted_call(ag__.ld(node).layer, tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#     134
#     135                                 def get_state_5():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent.py in tf____call__(self, inputs, initial_state, constants, **kwargs)
#     182                 flat_additional_inputs = ag__.Undefined('flat_additional_inputs')
#     183                 tensor = ag__.Undefined('tensor')
# --> 184                 ag__.if_stmt(ag__.and_((lambda : (ag__.ld(initial_state) is None)), (lambda : (ag__.ld(constants) is None))), if_body_7, else_body_7, get_state_8, set_state_8, ('do_return', "kwargs['constants']", "kwargs['initial_state']", 'retval_', 'self._num_constants', 'self.constants_spec', 'self.input_spec', 'self.state_spec'), 8)
#     185                 return fscope.ret(retval_, do_return)
#     186         return tf____call__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent.py in if_body_7()
#      22                     try:
#      23                         do_return = True
# ---> 24                         retval_ = ag__.converted_call(ag__.converted_call(ag__.ld(super), (ag__.ld(RNN), ag__.ld(self)), None, fscope).__call__, (ag__.ld(inputs),), dict(**ag__.ld(kwargs)), fscope)
#      25                     except:
#      26                         do_return = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py in tf____call__(self, *args, **kwargs)
#     197                 mask_is_implicit = ag__.Undefined('mask_is_implicit')
#     198                 outputs = ag__.Undefined('outputs')
# --> 199                 ag__.if_stmt(ag__.converted_call(ag__.ld(_in_functional_construction_mode), (ag__.ld(self), ag__.ld(inputs), ag__.ld(args), ag__.ld(kwargs), ag__.ld(input_list)), None, fscope), if_body_10, else_body_10, get_state_10, set_state_10, ('do_return', "kwargs['mask']", 'retval_', 'args', 'input_list', 'inputs', 'kwargs'), 3)
#     200                 return fscope.ret(retval_, do_return)
#     201         return tf____call__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py in else_body_10()
#     143                             ag__.if_stmt(ag__.ld(self)._autocast, if_body_6, else_body_6, get_state_6, set_state_6, ('inputs',), 1)
#     144                             with ag__.ld(autocast_variable).enable_auto_cast_variables(ag__.ld(self)._compute_dtype_object):
# --> 145                                 outputs = ag__.converted_call(ag__.ld(call_fn), ((ag__.ld(inputs),) + tuple(ag__.ld(args))), dict(**ag__.ld(kwargs)), fscope)
#     146
#     147                             def get_state_7():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent_v2.py in tf__call(self, inputs, mask, training, initial_state)
#     167                 runtime = ag__.Undefined('runtime')
#     168                 outputs = ag__.Undefined('outputs')
# --> 169                 ag__.if_stmt(ag__.or_((lambda : ag__.ld(is_ragged_input)), (lambda : ag__.not_(ag__.ld(self)._could_use_gpu_kernel))), if_body_5, else_body_5, get_state_5, set_state_5, ('kwargs', 'last_output', 'outputs', 'runtime', 'states', 'inputs'), 5)
#     170
#     171                 def get_state_6():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1170     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1171   else:
# -> 1172     _py_if_stmt(cond, body, orelse)
#    1173
#    1174
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1223 def _py_if_stmt(cond, body, orelse):
#    1224   """Overload of if_stmt that executes a Python if statement."""
# -> 1225   return body() if cond else orelse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent_v2.py in if_body_5()
#      55                                 raise
#      56                             return fscope_1.ret(retval__1, do_return_1)
# ---> 57                     (last_output, outputs, states) = ag__.converted_call(ag__.ld(backend).rnn, (ag__.ld(step), ag__.ld(inputs), ag__.ld(initial_state)), dict(constants=None, go_backwards=ag__.ld(self).go_backwards, mask=ag__.ld(mask), unroll=ag__.ld(self).unroll, input_length=ag__.if_exp((ag__.ld(row_lengths) is not None), (lambda : ag__.ld(row_lengths)), (lambda : ag__.ld(timesteps)), '(row_lengths is not None)'), time_major=ag__.ld(self).time_major, zero_output_for_mask=ag__.ld(self).zero_output_for_mask), fscope)
#      58                     runtime = ag__.converted_call(ag__.ld(_runtime), (ag__.ld(_RUNTIME_UNKNOWN),), None, fscope)
#      59
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in tf__wrapper(*args, **kwargs)
#      15                     try:
#      16                         do_return = True
# ---> 17                         retval_ = ag__.converted_call(ag__.ld(target), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      18                     except:
#      19                         do_return = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     430   try:
#     431     program_ctx = converter.ProgramContext(options=options)
# --> 432     converted_f = _convert_actual(target_entity, program_ctx)
#     433     if logging.has_verbosity(2):
#     434       _log_callargs(converted_f, effective_args, kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in _convert_actual(entity, program_ctx)
#     272                      ' try passing f.python_function instead.')
#     273
# --> 274   transformed, module, source_map = _TRANSPILER.transform(entity, program_ctx)
#     275
#     276   assert not hasattr(transformed, 'ag_module')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform(self, obj, user_context)
#     284     """
#     285     if inspect.isfunction(obj) or inspect.ismethod(obj):
# --> 286       return self.transform_function(obj, user_context)
#     287
#     288     raise NotImplementedError('Non-function: {}'.format(type(obj)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, user_context)
#     468           logging.log(1, '%s is not cached for subkey %s', fn, cache_subkey)
#     469           # TODO(mdan): Confusing overloading pattern. Fix.
# --> 470           nodes, ctx = super(PyToPy, self).transform_function(fn, user_context)
#     471
#     472           if isinstance(nodes, gast.Lambda):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, user_context)
#     361
#     362     node = self._erase_arg_defaults(node)
# --> 363     result = self.transform_ast(node, context)
#     364
#     365     return result, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py in transform_ast(self, node, ctx)
#     256       node = slices.transform(node, ctx)
#     257     node = call_trees.transform(node, ctx)
# --> 258     node = control_flow.transform(node, ctx)
#     259     node = conditional_expressions.transform(node, ctx)
#     260     node = logical_expressions.transform(node, ctx)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/converters/control_flow.py in transform(node, ctx)
#     414   node = liveness.resolve(node, ctx, graphs)
#     415
# --> 416   node = ControlFlowTransformer(ctx).visit(node)
#     417   return node
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/converters/control_flow.py in visit_FunctionDef(self, node)
#      52     with self.state[_Function] as fn:
#      53       fn.scope = anno.getanno(node, annos.NodeAnno.BODY_SCOPE)
# ---> 54       return self.generic_visit(node)
#      55
#      56   def _create_nonlocal_declarations(self, vars_):
#
# ~/opt/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/converters/control_flow.py in visit_If(self, node)
#     204
#     205   def visit_If(self, node):
# --> 206     node = self.generic_visit(node)
#     207     body_scope = anno.getanno(node, annos.NodeAnno.BODY_SCOPE)
#     208     orelse_scope = anno.getanno(node, annos.NodeAnno.ORELSE_SCOPE)
#
# ~/opt/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/converters/control_flow.py in visit_FunctionDef(self, node)
#      52     with self.state[_Function] as fn:
#      53       fn.scope = anno.getanno(node, annos.NodeAnno.BODY_SCOPE)
# ---> 54       return self.generic_visit(node)
#      55
#      56   def _create_nonlocal_declarations(self, vars_):
#
# ~/opt/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/ast.py in generic_visit(self, node)
#     437                 for value in old_value:
#     438                     if isinstance(value, AST):
# --> 439                         value = self.visit(value)
#     440                         if value is None:
#     441                             continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/core/converter.py in visit(self, node)
#     317     self._ast_depth += 1
#     318     try:
# --> 319       return super(Base, self).visit(node)
#     320     finally:
#     321       self._ast_depth -= 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/transformer.py in visit(self, node)
#     443         entry_expr_value = node.value
#     444
# --> 445       result = super(Base, self).visit(node)
#     446
#     447       # Adjust for consistency: replacing the value of an Expr with
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/converters/control_flow.py in visit_If(self, node)
#     243         nouts)
#     244     """
# --> 245     new_nodes = templates.replace(
#     246         template,
#     247         body=node.body,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/templates.py in replace(template, **replacements)
#     262     replacements[k] = _convert_to_ast(replacements[k])
#     263   template_str = parser.STANDARD_PREAMBLE + textwrap.dedent(template)
# --> 264   nodes = parser.parse(
#     265       template_str,
#     266       preamble_len=parser.STANDARD_PREAMBLE_LEN,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/parser.py in parse(src, preamble_len, single_node)
#     338     ast.AST
#     339   """
# --> 340   module_node = gast.parse(src)
#     341   nodes = module_node.body
#     342   if preamble_len:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/gast.py in parse(*args, **kwargs)
#     298
#     299 def parse(*args, **kwargs):
# --> 300     return ast_to_gast(_ast.parse(*args, **kwargs))
#     301
#     302
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/ast3.py in ast_to_gast(node)
#     435
#     436 def ast_to_gast(node):
# --> 437     return Ast3ToGAst().visit(node)
#     438
#     439
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in generic_visit(self, node)
#      22             new_node = getattr(to, cls)()
#      23             for field in node._fields:
# ---> 24                 setattr(new_node, field, self._visit(getattr(node, field)))
#      25             for attr in getattr(node, '_attributes'):
#      26                 if hasattr(node, attr):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#       9         def _visit(self, node):
#      10             if isinstance(node, list):
# ---> 11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
#      13                 return self.visit(node)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in <listcomp>(.0)
#       9         def _visit(self, node):
#      10             if isinstance(node, list):
# ---> 11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
#      13                 return self.visit(node)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#      11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
# ---> 13                 return self.visit(node)
#      14             else:
#      15                 return node
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in generic_visit(self, node)
#      22             new_node = getattr(to, cls)()
#      23             for field in node._fields:
# ---> 24                 setattr(new_node, field, self._visit(getattr(node, field)))
#      25             for attr in getattr(node, '_attributes'):
#      26                 if hasattr(node, attr):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#       9         def _visit(self, node):
#      10             if isinstance(node, list):
# ---> 11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
#      13                 return self.visit(node)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in <listcomp>(.0)
#       9         def _visit(self, node):
#      10             if isinstance(node, list):
# ---> 11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
#      13                 return self.visit(node)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#      11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
# ---> 13                 return self.visit(node)
#      14             else:
#      15                 return node
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in generic_visit(self, node)
#      22             new_node = getattr(to, cls)()
#      23             for field in node._fields:
# ---> 24                 setattr(new_node, field, self._visit(getattr(node, field)))
#      25             for attr in getattr(node, '_attributes'):
#      26                 if hasattr(node, attr):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#      11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
# ---> 13                 return self.visit(node)
#      14             else:
#      15                 return node
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/ast3.py in visit_Name(self, node)
#     174         new_node = gast.Name(
#     175             self._visit(node.id),
# --> 176             self._visit(node.ctx),
#     177             None,
#     178             None,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in _visit(self, node)
#      11                 return [self._visit(n) for n in node]
#      12             elif isinstance(node, ast.AST):
# ---> 13                 return self.visit(node)
#      14             else:
#      15                 return node
#
# ~/opt/anaconda3/lib/python3.8/ast.py in visit(self, node)
#     361         method = 'visit_' + node.__class__.__name__
#     362         visitor = getattr(self, method, self.generic_visit)
# --> 363         return visitor(node)
#     364
#     365     def generic_visit(self, node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/astn.py in generic_visit(self, node)
#      20             if not hasattr(to, cls):
#      21                 return
# ---> 22             new_node = getattr(to, cls)()
#      23             for field in node._fields:
#      24                 setattr(new_node, field, self._visit(getattr(node, field)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gast/gast.py in create_node(self, *args, **kwargs)
#      22         for argname, argval in zip(self._fields, args):
#      23             setattr(self, argname, argval)
# ---> 24         for argname, argval in kwargs.items():
#      25             assert argname in Fields, \
#      26                     "Invalid Keyword argument for {}: {}".format(Name, argname)
#
# KeyboardInterrupt:

# %%
print('Test score:', score)
print('Test accuracy:', acc)

# %% [markdown]
# ## Confusion Matrix

# %%
p = model.predict(X_test, verbose=2) # to predict probability
y_pred = np.argmax(p, axis=-1)
target_names = list(sdf.race.astype('category').cat.categories)
print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names))
print(confusion_matrix(np.argmax(y_test, axis=1), y_pred))

# %% [markdown]
# ## Save model

# %%
model.save('../models/fl_voter_reg/lstm/fl_all_ln_lstm_5_cat.h5')

# %%
words_df = pd.DataFrame(words_list, columns=['vocab'])
words_df.to_csv('../dataverse_files/fl_voter_reg/lstm/fl_all_ln_vocab_5_cat.csv', index=False, encoding='utf-8')
